# %%
import pandas as pd

# %%
# 
df = pd.read_clipboard(usecols=["template_index", "label", "original_text", "masked_text", "template_text"], dtype=str).dropna()
df["template_index"] = df["template_index"].map(lambda x: int(x)+1)
df
# Out:
#     template_index label                                      original_text
# 0                1     1  an odd drama set in the world of lingerie mode...  \
# 1                2     1  twohy knows how to inflate the mundane into th...
# 2                3     0                                                  .
# 3                4     0                            what really happened ?
# 4                5     1                                       yes , soar .
# 5                6     0  you can practically hear george orwell turning...
# 6                7     0  when the twist endings were actually surprising ?
# 7                8     1  a dreadful day in irish history is given passi...
# 8                9     0  charly comes off as emotionally manipulative a...
# 9               10     0  the rules of attraction gets us too drunk on t...
# 10              11     1  the film may not hit as hard as some of the be...
# ...

# %%
df.to_csv("generated_templates/generated_templates_random.csv", index=False)
