# %% [markdown]
# # Abordagem 5
#
# Usando a abordagem 5 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística "Vocabulary" com o teste MFT.
#
# As etapas desta abordagem são:
#
# 1. Quebrar as instâncias em sentenças
# 2. Rankear as palavras de cada sentença
# 3. Filtrar as sentenças pelo tamanho (maior ou igual a 5 palavras)
# 4. Filtrar sentenças com palavras relevantes (verbos ou adjetivos)
# 5. Filtrar sentenças com alta confiança na predição das palavras relevantes da etapa anterior
# 6. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
from datasets import load_dataset

dataset = load_dataset("amazon_polarity")
dataset.set_format("pandas")
df = dataset["test"].shuffle(seed=42)[:100]
df = df.rename(columns={"content": "text"}).drop(columns=["title"])
df
# Out:
#     label
# 0       1  \
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# 95      1
# 96      0
# 97      0
# 98      0
# 99      1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text
# 0                                                                                                                                                                                                                                                                           The product works fine. I ordered the more exprensive one after I read reviews from others on Amazon. My husband likes the presser. It does a good job pressing his pants. However, it was damaged in the box when we received it. We decided it was too much trouble to send it back. The box was torn and the presser had a chuck knocked out of it.
# 1                                                                                                                                                                                                                                 This book is so useless that I feel compelled to write a review to warn others to stay away from this book. A good tutorial should inspire the user on what he/she can do with the product. This book leads you to believe that without talent, the only thing you can do with Illustrator is to draw circles and squares. The book is a disservice to both the reader and to Adobe Illustrator.
# 2                                                                                                            The authors attempt an ambitious goal of covering many SOA topics - but their resulting text come across as scattered - vague - and lacking a coherent and practical application.Thomas Erl's books are much better written - and have a coherent approch to buliding a solid body of knowledge.For a manager / salesperson wanting a broad overview of SOA - they might be better served by reading Service Oriented Architecture For DummiesService Oriented Architecture For Dummies (For Dummies (Computer/Tech))
# 3                                                                                                                                                                                                                                                                                                                                                                                          I ordered this product and did recieve then a couple months later it broke. Now Ive done everything I was told to do by by shipping back for a replacement and nothing. They wont return Emails i havent received the replacement part.
# 4                                                                                                                                                                            I hated this movie. It was so silly. The girl made the cult look more stupid than they already were. Come on? She was from the future??? I can't stop laughing. Maybe, I missed something. I don't think I did. When it first started, I said to myself: What am I watching this for? I thought it was stupid, stupid and then more stupid. I kept watching, trying to make sense of it, but to no avail. I didn't want to waste my $1.00 rental fee.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 95                                                                     What a gloriously funny book! Even the recipies were funny, and well, how funny did you think a recipie could be?! I "discovered" this book en route to Jamaica back in May--the stranger next to me read it all the way there. Well, the cover just grabbed me and I HAD to have it. It was a quick, light read that had a very wise and uplifting last chapter. Oh, and for those who are clueless like me in the beginning, this is not a fiction novel, but a wacky manual about life, love and other good stuff that we should all follow to the hilt!
# 96  If you want Harman Kardon receivers it's ok. Even most of the DVD's. I own a 22 and a 31 and I also got this one which is really annoying.Issues:- it does not save caption settings- it does not save video settings; even after I set it up to be 16:9 1080i default it always reverted to 720p.- after a period of time the DVD unit itself refused to read discsI returned to HK, got a replacement and I'm testing it to see if there are any improvements, but... I think this is unacceptable for HK. After all I did not buy an 80$ Sony, and if I bought HK I bought it for the name which supposedley means quality.
# 97                                                                                                                                                                                                                                                                                                        Same problems as everybody else. 14 months after purchase it ate the card. Tried 2 different cards, no dice for either. From love to hate. Dang. Also Canon's support website/acknowledgement of this problem is non-existent. It was hard enough to navigate their site, but it's impossible to find anything relevant.
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I can be tough on safety glasses so it may be no fault of the mfg but IMO the lenses scuffed and scratched rather quickly.
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Love the quick drawing action, works beautifully! Great knife at a great price. Get you one son!
#
# [100 rows x 2 columns]

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
rotten_tomatoes_models = {
    'bert': 'pig4431/amazonPolarity_BERT_5E', 
    'distilbert': 'pig4431/amazonPolarity_DistilBERT_5E', 
    'roberta': 'pig4431/amazonPolarity_roBERTa_5E', 
    'albert': 'pig4431/amazonPolarity_ALBERT_5E',
    'xlnet': 'pig4431/amazonPolarity_XLNET_5E', 
}

# %%
m1 = load_model(rotten_tomatoes_models['albert'])
m2 = load_model(rotten_tomatoes_models['distilbert'])
m3 = load_model(rotten_tomatoes_models['roberta'])
m4 = load_model(rotten_tomatoes_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(rotten_tomatoes_models['bert'])
# Out:
# Loading model pig4431/amazonPolarity_ALBERT_5E...
# Loading model pig4431/amazonPolarity_DistilBERT_5E...
# Loading model pig4431/amazonPolarity_roBERTa_5E...
# Loading model pig4431/amazonPolarity_XLNET_5E...
# Loading model pig4431/amazonPolarity_BERT_5E...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp5

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
tg = PosNegTemplateGeneratorApp5(model, models)
templates = tg.generate_templates(instances, n_masks=2, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 22 sentences were generated.
# Ranking words using Replace-1 Score...
# /tmp/ipykernel_29582/1831943719.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 22 sentences remaining.
# Filtering instances by relevant words...
# :: 8 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 3 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 1m 15.8s
# filipe: 41.6s

# %%
tg.to_dataframe()
# Out:
#    label
# 0      0  \
# 1      0
# 2      1
#
#                                                                                       original_text
# 0  The opening is so small, that anything larger or longer than a cheerio is impossible to pick up.  \
# 1                                                               It got boring and monotonous quick.
# 2                                                      Huggies customer service is amazing as well!
#
#                                                                                               masked_text
# 0  The opening {mask} so small , that anything larger or {mask} than a cheerio is impossible to pick up .  \
# 1                                                                     It {mask} boring and {mask} quick .
# 2                                                        Huggies customer service {mask} {mask} as well !
#
#                                                                                                    template_text
# 0  The opening {neg_verb} so small , that anything larger or {neg_adj} than a cheerio is impossible to pick up .
# 1                                                                     It {neg_verb} boring and {neg_adj} quick .
# 2                                                        Huggies customer service {neg_verb} {pos_adj} as well !

# %%
tg.lexicons
# Out:
# {'pos_verb': [],
#  'neg_verb': ['got', 'is'],
#  'pos_adj': ['amazing'],
#  'neg_adj': ['longer', 'monotonous']}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in df['text'].values]

# %%
# %%time
# 1m 9.1s
tg = PosNegTemplateGeneratorApp5(model, models)
templates = tg.generate_templates(instances, n_masks=2, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 467 sentences were generated.
# Ranking words using Replace-1 Score...
# /tmp/ipykernel_29582/1831943719.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 439 sentences remaining.
# Filtering instances by relevant words...
# :: 172 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 107 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.
# CPU times: user 48min 25s, sys: 1.06 s, total: 48min 26s
# Wall time: 5min 15s

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 1m 5.6s

# %%
df_templates = tg.to_dataframe()
df_templates.insert(0, "template_index", df_templates.index.map(lambda x: int(x)+1))
df_templates
# Out:
#      template_index  label
# 0                 1      1  \
# 1                 2      0
# 2                 3      1
# 3                 4      0
# 4                 5      0
# ..              ...    ...
# 102             103      0
# 103             104      1
# 104             105      1
# 105             106      0
# 106             107      1
#
#                                                                                                                         original_text
# 0                                                                                                             The product works fine.  \
# 1                                                       I ordered the more exprensive one after I read reviews from others on Amazon.
# 2                                                                                              It does a good job pressing his pants.
# 3                         This book is so useless that I feel compelled to write a review to warn others to stay away from this book.
# 4                                                                     The girl made the cult look more stupid than they already were.
# ..                                                                                                                                ...
# 102                                                                                         we are addicted to LOST...silly as it is.
# 103  after purchasing a roku box, which came with a $certificate for amazon VOD....i was able to purchase season 6 for a great price.
# 104                                                                                      If you want Harman Kardon receivers it's ok.
# 105                                         It was hard enough to navigate their site, but it's impossible to find anything relevant.
# 106                                                                                 Love the quick drawing action, works beautifully!
#
#                                                                                                                                   masked_text
# 0                                                                                                                 The product {mask} {mask} .  \
# 1                                                                   I {mask} the more {mask} one after I read reviews from others on Amazon .
# 2                                                                                                 It {mask} a {mask} job pressing his pants .
# 3                                    This book is so {mask} that I feel {mask} to write a review to warn others to stay away from this book .
# 4                                                                          The girl made the cult {mask} more {mask} than they already were .
# ..                                                                                                                                        ...
# 102                                                                                              we are {mask} to {mask} ... silly as it is .
# 103  after purchasing a roku box , which {mask} with a $ certificate for amazon VOD .... i was able to purchase season 6 for a {mask} price .
# 104                                                                                    If you want Harman Kardon receivers it {mask} {mask} .
# 105                                                    It was hard enough to navigate their site , but it 's {mask} to find anything {mask} .
# 106                                                                                    {mask} the quick drawing action , {mask} beautifully !
#
#                                                                                                                                        template_text
# 0                                                                                                                 The product {neg_verb} {pos_adj} .
# 1                                                                   I {pos_verb} the more {pos_adj} one after I read reviews from others on Amazon .
# 2                                                                                                 It {neg_verb} a {pos_adj} job pressing his pants .
# 3                                    This book is so {neg_adj} that I feel {neg_verb} to write a review to warn others to stay away from this book .
# 4                                                                          The girl made the cult {neg_verb} more {neg_adj} than they already were .
# ..                                                                                                                                               ...
# 102                                                                                             we are {pos_verb} to {neg_verb} ... silly as it is .
# 103  after purchasing a roku box , which {pos_verb} with a $ certificate for amazon VOD .... i was able to purchase season 6 for a {pos_adj} price .
# 104                                                                                    If you want Harman Kardon receivers it {neg_verb} {pos_adj} .
# 105                                                     It was hard enough to navigate their site , but it 's {neg_adj} to find anything {neg_adj} .
# 106                                                                                   {pos_verb} the quick drawing action , {neg_verb} beautifully !
#
# [107 rows x 5 columns]

# %%
df_templates.to_csv("generated_templates/generated_templates_approach5.csv", index=False)

# %%
print(tg.lexicons)
# Out:
# {'pos_verb': ['hearing', 'mesmerizing', 'discovering', 'liked', 'Love', 'love', 'demonstrated', 'finding', "'ll", 'recommend', 'found', 'addicted', 'loaded', 'provides', 'evolving', 'entertaining.The', 'start', 'laughing', 'reborn', 'beginning', 'must', 'have', 'adding', 'ordered', 'find', 'understand', 'came', 'repaired'], 'neg_verb': ['did', 'was', 'make', 'cost', 'went', 'looking', 'mention', 'crossing', 'waste', 'meddling', 'ripped', "'m", 'passing', 'like', 'play', 'supposed', 'look', 'were', 'remained', 'been', 'based', 'got', 'surprised', 'be', 'does', 'experenced', 'shorted', "'s", 'compelled', 'seemed', 'being', 'threw', 'use', 'leaked', 'works', 'would', 'Being', 'killed', 'had', 'fix', 'are', 'suggest', 'happens', 'fall', 'bought', 'think', 'Do', 'prompted', 'made', 'is', 'saw', 'makes', 'LOST', 'stop', 'hurt', 'do', 'dissappointed', 'looked', "'ve"], 'pos_adj': ['outstanding', 'fun', 'fine', 'true', 'more', 'new', 'due', 'funniest', 'worth', 'nice', 'ultimate', 'good', 'solid', 'handsome', 'exprensive', 'rushed', 'expensive', 'ok', 'aware', 'favorite', 'absolute', 'amazing', 'rich', 'excited', 'handy', 'great'], 'neg_adj': ['useless', 'ignored', 'convoluted', 'common', 'poor', 'monotonous', 'impossible', 'reasonable', 'messianic', 'previous', 'like', 'cant', 'implausible', 'inadequate', 'initial', 'incompatible', 'insane', 'second', 'Babble', 'worst', 'stupid', 'longer', 'similar', 'french', 'ridiculous', 'little', 'disapointed', 'weak', 'frozen', 'relevant', 'setting', 'strange', 'dissapointed', 'worse', 'least', 'only', 'terrible', 'old']}

# %% [markdown]
# # Usando os templates gerados pelo TemplateGenerator no CheckList

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT
# Out:
# /home/filipegl/miniconda3/envs/checklist-templates/lib/python3.11/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_verb', lexicons['pos_verb'])
editor.add_lexicon('neg_verb', lexicons['neg_verb'])
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
suite.save('./suites/posneg-approach5.suite')
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 1534 examples
# /tmp/ipykernel_29582/1831943719.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 728 examples
# Running Test: MFT with vocabullary - template3
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template4
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template5
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template6
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template7
# Predicting 59 examples
# Running Test: MFT with vocabullary - template8
# Predicting 59 examples
# Running Test: MFT with vocabullary - template9
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template10
# Predicting 1064 examples
# Running Test: MFT with vocabullary - template11
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template12
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template13
# Predicting 38 examples
# Running Test: MFT with vocabullary - template14
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template15
# Predicting 728 examples
# Running Test: MFT with vocabullary - template16
# Predicting 59 examples
# Running Test: MFT with vocabullary - template17
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template18
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template19
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template20
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template21
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template22
# Predicting 988 examples
# Running Test: MFT with vocabullary - template23
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template24
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template25
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template26
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template27
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template28
# Predicting 728 examples
# Running Test: MFT with vocabullary - template29
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template30
# Predicting 988 examples
# Running Test: MFT with vocabullary - template31
# Predicting 988 examples
# Running Test: MFT with vocabullary - template32
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template33
# Predicting 38 examples
# Running Test: MFT with vocabullary - template34
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template35
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template36
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template37
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template38
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template39
# Predicting 59 examples
# Running Test: MFT with vocabullary - template40
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template41
# Predicting 728 examples
# Running Test: MFT with vocabullary - template42
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template43
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template44
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template45
# Predicting 59 examples
# Running Test: MFT with vocabullary - template46
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template47
# Predicting 28 examples
# Running Test: MFT with vocabullary - template48
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template49
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template50
# Predicting 59 examples
# Running Test: MFT with vocabullary - template51
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template52
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template53
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template54
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template55
# Predicting 38 examples
# Running Test: MFT with vocabullary - template56
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template57
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template58
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template59
# Predicting 728 examples
# Running Test: MFT with vocabullary - template60
# Predicting 59 examples
# Running Test: MFT with vocabullary - template61
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template62
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template63
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template64
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template65
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template66
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template67
# Predicting 59 examples
# Running Test: MFT with vocabullary - template68
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template69
# Predicting 59 examples
# Running Test: MFT with vocabullary - template70
# Predicting 1064 examples
# Running Test: MFT with vocabullary - template71
# Predicting 988 examples
# Running Test: MFT with vocabullary - template72
# Predicting 28 examples
# Running Test: MFT with vocabullary - template73
# Predicting 28 examples
# Running Test: MFT with vocabullary - template74
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template75
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template76
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template77
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template78
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template79
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template80
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template81
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template82
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template83
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template84
# Predicting 988 examples
# Running Test: MFT with vocabullary - template85
# Predicting 59 examples
# Running Test: MFT with vocabullary - template86
# Predicting 59 examples
# Running Test: MFT with vocabullary - template87
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template88
# Predicting 1064 examples
# Running Test: MFT with vocabullary - template89
# Predicting 26 examples
# Running Test: MFT with vocabullary - template90
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template91
# Predicting 59 examples
# Running Test: MFT with vocabullary - template92
# Predicting 1064 examples
# Running Test: MFT with vocabullary - template93
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template94
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template95
# Predicting 59 examples
# Running Test: MFT with vocabullary - template96
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template97
# Predicting 2241 examples
# Running Test: MFT with vocabullary - template98
# Predicting 59 examples
# Running Test: MFT with vocabullary - template99
# Predicting 59 examples
# Running Test: MFT with vocabullary - template100
# Predicting 988 examples
# Running Test: MFT with vocabullary - template101
# Predicting 59 examples
# Running Test: MFT with vocabullary - template102
# Predicting 59 examples
# Running Test: MFT with vocabullary - template103
# Predicting 1652 examples
# Running Test: MFT with vocabullary - template104
# Predicting 728 examples
# Running Test: MFT with vocabullary - template105
# Predicting 1534 examples
# Running Test: MFT with vocabullary - template106
# Predicting 38 examples
# Running Test: MFT with vocabullary - template107
# Predicting 1652 examples

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach5.suite')

# suite.visual_summary_table()

# %%
passed = 0
failed = 0
for test_name in suite.tests:
    table = suite.visual_summary_by_test(test_name)
    
    failed += table.stats['nfailed']    
    passed += table.stats['npassed']
    assert table.stats['nfailed'] + table.stats['npassed'] == len(table.filtered_testcases)

print(f"{failed = } ({(failed/(passed+failed))*100:.2f}%)")
print(f"{passed = } ({(passed/(passed+failed))*100:.2f}%)")
print(f"total = {passed+failed}")
print("templates:", len(suite.tests))
# Out:
# failed = 35284 (25.34%)
# passed = 103932 (74.66%)
# total = 139216
# templates: 107

# %%
table = suite.visual_summary_by_test('Test: MFT with vocabullary - template3')

for item in table.candidate_testcases:
    print(item['examples'][0]['new']['text'])
# Out:
# It cost a outstanding job pressing his pants .
# It waste a outstanding job pressing his pants .
# It killed a outstanding job pressing his pants .
# It LOST a outstanding job pressing his pants .
# It hurt a outstanding job pressing his pants .
# It dissappointed a outstanding job pressing his pants .
# It cost a fun job pressing his pants .
# It waste a fun job pressing his pants .
# It shorted a fun job pressing his pants .
# It killed a fun job pressing his pants .
# It LOST a fun job pressing his pants .
# It hurt a fun job pressing his pants .
# It dissappointed a fun job pressing his pants .
# It cost a fine job pressing his pants .
# It waste a fine job pressing his pants .
# It shorted a fine job pressing his pants .
# It leaked a fine job pressing his pants .
# It killed a fine job pressing his pants .
# It LOST a fine job pressing his pants .
# It hurt a fine job pressing his pants .
# It dissappointed a fine job pressing his pants .
# It cost a true job pressing his pants .
# It waste a true job pressing his pants .
# It ripped a true job pressing his pants .
# It supposed a true job pressing his pants .
# It remained a true job pressing his pants .
# It shorted a true job pressing his pants .
# It use a true job pressing his pants .
# It leaked a true job pressing his pants .
# It would a true job pressing his pants .
# It killed a true job pressing his pants .
# It suggest a true job pressing his pants .
# It LOST a true job pressing his pants .
# It hurt a true job pressing his pants .
# It dissappointed a true job pressing his pants .
# It looked a true job pressing his pants .
# It did a more job pressing his pants .
# It was a more job pressing his pants .
# It cost a more job pressing his pants .
# It went a more job pressing his pants .
# It looking a more job pressing his pants .
# It mention a more job pressing his pants .
# It crossing a more job pressing his pants .
# It waste a more job pressing his pants .
# It meddling a more job pressing his pants .
# It ripped a more job pressing his pants .
# It 'm a more job pressing his pants .
# It passing a more job pressing his pants .
# It like a more job pressing his pants .
# It play a more job pressing his pants .
# It supposed a more job pressing his pants .
# It look a more job pressing his pants .
# It were a more job pressing his pants .
# It remained a more job pressing his pants .
# It been a more job pressing his pants .
# It based a more job pressing his pants .
# It got a more job pressing his pants .
# It surprised a more job pressing his pants .
# It be a more job pressing his pants .
# It experenced a more job pressing his pants .
# It shorted a more job pressing his pants .
# It 's a more job pressing his pants .
# It compelled a more job pressing his pants .
# It seemed a more job pressing his pants .
# It being a more job pressing his pants .
# It threw a more job pressing his pants .
# It use a more job pressing his pants .
# It leaked a more job pressing his pants .
# It would a more job pressing his pants .
# It Being a more job pressing his pants .
# It killed a more job pressing his pants .
# It had a more job pressing his pants .
# It fix a more job pressing his pants .
# It are a more job pressing his pants .
# It suggest a more job pressing his pants .
# It happens a more job pressing his pants .
# It fall a more job pressing his pants .
# It think a more job pressing his pants .
# It Do a more job pressing his pants .
# It is a more job pressing his pants .
# It saw a more job pressing his pants .
# It LOST a more job pressing his pants .
# It stop a more job pressing his pants .
# It hurt a more job pressing his pants .
# It do a more job pressing his pants .
# It dissappointed a more job pressing his pants .
# It looked a more job pressing his pants .
# It 've a more job pressing his pants .
# It cost a new job pressing his pants .
# It looking a new job pressing his pants .
# It mention a new job pressing his pants .
# It waste a new job pressing his pants .
# It ripped a new job pressing his pants .
# It like a new job pressing his pants .
# It supposed a new job pressing his pants .
# It look a new job pressing his pants .
# It were a new job pressing his pants .
# It remained a new job pressing his pants .
# It be a new job pressing his pants .
# It shorted a new job pressing his pants .
# It seemed a new job pressing his pants .
# It being a new job pressing his pants .
# It threw a new job pressing his pants .
# It use a new job pressing his pants .
# It leaked a new job pressing his pants .
# It would a new job pressing his pants .
# It Being a new job pressing his pants .
# It killed a new job pressing his pants .
# It suggest a new job pressing his pants .
# It think a new job pressing his pants .
# It LOST a new job pressing his pants .
# It stop a new job pressing his pants .
# It hurt a new job pressing his pants .
# It dissappointed a new job pressing his pants .
# It looked a new job pressing his pants .
# It make a due job pressing his pants .
# It cost a due job pressing his pants .
# It went a due job pressing his pants .
# It looking a due job pressing his pants .
# It mention a due job pressing his pants .
# It waste a due job pressing his pants .
# It meddling a due job pressing his pants .
# It ripped a due job pressing his pants .
# It 'm a due job pressing his pants .
# It like a due job pressing his pants .
# It play a due job pressing his pants .
# It supposed a due job pressing his pants .
# It look a due job pressing his pants .
# It remained a due job pressing his pants .
# It based a due job pressing his pants .
# It got a due job pressing his pants .
# It surprised a due job pressing his pants .
# It be a due job pressing his pants .
# It experenced a due job pressing his pants .
# It shorted a due job pressing his pants .
# It seemed a due job pressing his pants .
# It threw a due job pressing his pants .
# It use a due job pressing his pants .
# It leaked a due job pressing his pants .
# It would a due job pressing his pants .
# It killed a due job pressing his pants .
# It had a due job pressing his pants .
# It suggest a due job pressing his pants .
# It fall a due job pressing his pants .
# It think a due job pressing his pants .
# It Do a due job pressing his pants .
# It prompted a due job pressing his pants .
# It made a due job pressing his pants .
# It saw a due job pressing his pants .
# It makes a due job pressing his pants .
# It LOST a due job pressing his pants .
# It stop a due job pressing his pants .
# It hurt a due job pressing his pants .
# It do a due job pressing his pants .
# It dissappointed a due job pressing his pants .
# It looked a due job pressing his pants .
# It 've a due job pressing his pants .
# It LOST a funniest job pressing his pants .
# It cost a worth job pressing his pants .
# It waste a worth job pressing his pants .
# It ripped a worth job pressing his pants .
# It supposed a worth job pressing his pants .
# It surprised a worth job pressing his pants .
# It shorted a worth job pressing his pants .
# It threw a worth job pressing his pants .
# It use a worth job pressing his pants .
# It leaked a worth job pressing his pants .
# It would a worth job pressing his pants .
# It killed a worth job pressing his pants .
# It prompted a worth job pressing his pants .
# It LOST a worth job pressing his pants .
# It stop a worth job pressing his pants .
# It hurt a worth job pressing his pants .
# It dissappointed a worth job pressing his pants .
# It cost a nice job pressing his pants .
# It waste a nice job pressing his pants .
# It ripped a nice job pressing his pants .
# It remained a nice job pressing his pants .
# It be a nice job pressing his pants .
# It shorted a nice job pressing his pants .
# It use a nice job pressing his pants .
# It leaked a nice job pressing his pants .
# It would a nice job pressing his pants .
# It killed a nice job pressing his pants .
# It suggest a nice job pressing his pants .
# It LOST a nice job pressing his pants .
# It hurt a nice job pressing his pants .
# It dissappointed a nice job pressing his pants .
# It looked a nice job pressing his pants .
# It cost a ultimate job pressing his pants .
# It crossing a ultimate job pressing his pants .
# It waste a ultimate job pressing his pants .
# It ripped a ultimate job pressing his pants .
# It supposed a ultimate job pressing his pants .
# It remained a ultimate job pressing his pants .
# It surprised a ultimate job pressing his pants .
# It shorted a ultimate job pressing his pants .
# It seemed a ultimate job pressing his pants .
# It threw a ultimate job pressing his pants .
# It use a ultimate job pressing his pants .
# It leaked a ultimate job pressing his pants .
# It would a ultimate job pressing his pants .
# It killed a ultimate job pressing his pants .
# It suggest a ultimate job pressing his pants .
# It LOST a ultimate job pressing his pants .
# It stop a ultimate job pressing his pants .
# It hurt a ultimate job pressing his pants .
# It dissappointed a ultimate job pressing his pants .
# It looked a ultimate job pressing his pants .
# It cost a good job pressing his pants .
# It waste a good job pressing his pants .
# It ripped a good job pressing his pants .
# It shorted a good job pressing his pants .
# It leaked a good job pressing his pants .
# It would a good job pressing his pants .
# It killed a good job pressing his pants .
# It LOST a good job pressing his pants .
# It hurt a good job pressing his pants .
# It dissappointed a good job pressing his pants .
# It cost a solid job pressing his pants .
# It waste a solid job pressing his pants .
# It ripped a solid job pressing his pants .
# It surprised a solid job pressing his pants .
# It shorted a solid job pressing his pants .
# It leaked a solid job pressing his pants .
# It killed a solid job pressing his pants .
# It LOST a solid job pressing his pants .
# It hurt a solid job pressing his pants .
# It dissappointed a solid job pressing his pants .
# It cost a handsome job pressing his pants .
# It waste a handsome job pressing his pants .
# It ripped a handsome job pressing his pants .
# It shorted a handsome job pressing his pants .
# It killed a handsome job pressing his pants .
# It LOST a handsome job pressing his pants .
# It hurt a handsome job pressing his pants .
# It dissappointed a handsome job pressing his pants .
# It cost a exprensive job pressing his pants .
# It went a exprensive job pressing his pants .
# It looking a exprensive job pressing his pants .
# It mention a exprensive job pressing his pants .
# It waste a exprensive job pressing his pants .
# It meddling a exprensive job pressing his pants .
# It ripped a exprensive job pressing his pants .
# It like a exprensive job pressing his pants .
# It play a exprensive job pressing his pants .
# It supposed a exprensive job pressing his pants .
# It look a exprensive job pressing his pants .
# It were a exprensive job pressing his pants .
# It remained a exprensive job pressing his pants .
# It surprised a exprensive job pressing his pants .
# It be a exprensive job pressing his pants .
# It shorted a exprensive job pressing his pants .
# It seemed a exprensive job pressing his pants .
# It use a exprensive job pressing his pants .
# It leaked a exprensive job pressing his pants .
# It would a exprensive job pressing his pants .
# It killed a exprensive job pressing his pants .
# It are a exprensive job pressing his pants .
# It suggest a exprensive job pressing his pants .
# It think a exprensive job pressing his pants .
# It LOST a exprensive job pressing his pants .
# It stop a exprensive job pressing his pants .
# It hurt a exprensive job pressing his pants .
# It dissappointed a exprensive job pressing his pants .
# It looked a exprensive job pressing his pants .
# It was a rushed job pressing his pants .
# It make a rushed job pressing his pants .
# It cost a rushed job pressing his pants .
# It went a rushed job pressing his pants .
# It looking a rushed job pressing his pants .
# It mention a rushed job pressing his pants .
# It crossing a rushed job pressing his pants .
# It waste a rushed job pressing his pants .
# It meddling a rushed job pressing his pants .
# It ripped a rushed job pressing his pants .
# It 'm a rushed job pressing his pants .
# It passing a rushed job pressing his pants .
# It like a rushed job pressing his pants .
# It play a rushed job pressing his pants .
# It supposed a rushed job pressing his pants .
# It look a rushed job pressing his pants .
# It were a rushed job pressing his pants .
# It remained a rushed job pressing his pants .
# It been a rushed job pressing his pants .
# It based a rushed job pressing his pants .
# It got a rushed job pressing his pants .
# It surprised a rushed job pressing his pants .
# It be a rushed job pressing his pants .
# It experenced a rushed job pressing his pants .
# It shorted a rushed job pressing his pants .
# It 's a rushed job pressing his pants .
# It compelled a rushed job pressing his pants .
# It seemed a rushed job pressing his pants .
# It being a rushed job pressing his pants .
# It threw a rushed job pressing his pants .
# It use a rushed job pressing his pants .
# It leaked a rushed job pressing his pants .
# It would a rushed job pressing his pants .
# It Being a rushed job pressing his pants .
# It killed a rushed job pressing his pants .
# It had a rushed job pressing his pants .
# It fix a rushed job pressing his pants .
# It are a rushed job pressing his pants .
# It suggest a rushed job pressing his pants .
# It happens a rushed job pressing his pants .
# It fall a rushed job pressing his pants .
# It think a rushed job pressing his pants .
# It Do a rushed job pressing his pants .
# It prompted a rushed job pressing his pants .
# It made a rushed job pressing his pants .
# It is a rushed job pressing his pants .
# It saw a rushed job pressing his pants .
# It makes a rushed job pressing his pants .
# It LOST a rushed job pressing his pants .
# It stop a rushed job pressing his pants .
# It hurt a rushed job pressing his pants .
# It do a rushed job pressing his pants .
# It dissappointed a rushed job pressing his pants .
# It looked a rushed job pressing his pants .
# It 've a rushed job pressing his pants .
# It was a expensive job pressing his pants .
# It make a expensive job pressing his pants .
# It cost a expensive job pressing his pants .
# It went a expensive job pressing his pants .
# It looking a expensive job pressing his pants .
# It mention a expensive job pressing his pants .
# It crossing a expensive job pressing his pants .
# It waste a expensive job pressing his pants .
# It meddling a expensive job pressing his pants .
# It ripped a expensive job pressing his pants .
# It 'm a expensive job pressing his pants .
# It passing a expensive job pressing his pants .
# It like a expensive job pressing his pants .
# It play a expensive job pressing his pants .
# It supposed a expensive job pressing his pants .
# It look a expensive job pressing his pants .
# It were a expensive job pressing his pants .
# It remained a expensive job pressing his pants .
# It been a expensive job pressing his pants .
# It based a expensive job pressing his pants .
# It got a expensive job pressing his pants .
# It surprised a expensive job pressing his pants .
# It be a expensive job pressing his pants .
# It experenced a expensive job pressing his pants .
# It shorted a expensive job pressing his pants .
# It 's a expensive job pressing his pants .
# It compelled a expensive job pressing his pants .
# It seemed a expensive job pressing his pants .
# It being a expensive job pressing his pants .
# It threw a expensive job pressing his pants .
# It use a expensive job pressing his pants .
# It leaked a expensive job pressing his pants .
# It would a expensive job pressing his pants .
# It Being a expensive job pressing his pants .
# It killed a expensive job pressing his pants .
# It had a expensive job pressing his pants .
# It are a expensive job pressing his pants .
# It suggest a expensive job pressing his pants .
# It happens a expensive job pressing his pants .
# It fall a expensive job pressing his pants .
# It think a expensive job pressing his pants .
# It Do a expensive job pressing his pants .
# It prompted a expensive job pressing his pants .
# It made a expensive job pressing his pants .
# It is a expensive job pressing his pants .
# It saw a expensive job pressing his pants .
# It makes a expensive job pressing his pants .
# It LOST a expensive job pressing his pants .
# It stop a expensive job pressing his pants .
# It hurt a expensive job pressing his pants .
# It do a expensive job pressing his pants .
# It dissappointed a expensive job pressing his pants .
# It looked a expensive job pressing his pants .
# It 've a expensive job pressing his pants .
# It was a ok job pressing his pants .
# It cost a ok job pressing his pants .
# It went a ok job pressing his pants .
# It looking a ok job pressing his pants .
# It mention a ok job pressing his pants .
# It crossing a ok job pressing his pants .
# It waste a ok job pressing his pants .
# It meddling a ok job pressing his pants .
# It ripped a ok job pressing his pants .
# It 'm a ok job pressing his pants .
# It like a ok job pressing his pants .
# It play a ok job pressing his pants .
# It supposed a ok job pressing his pants .
# It look a ok job pressing his pants .
# It were a ok job pressing his pants .
# It remained a ok job pressing his pants .
# It got a ok job pressing his pants .
# It surprised a ok job pressing his pants .
# It be a ok job pressing his pants .
# It experenced a ok job pressing his pants .
# It shorted a ok job pressing his pants .
# It seemed a ok job pressing his pants .
# It threw a ok job pressing his pants .
# It use a ok job pressing his pants .
# It leaked a ok job pressing his pants .
# It would a ok job pressing his pants .
# It killed a ok job pressing his pants .
# It had a ok job pressing his pants .
# It suggest a ok job pressing his pants .
# It happens a ok job pressing his pants .
# It fall a ok job pressing his pants .
# It think a ok job pressing his pants .
# It prompted a ok job pressing his pants .
# It saw a ok job pressing his pants .
# It LOST a ok job pressing his pants .
# It stop a ok job pressing his pants .
# It hurt a ok job pressing his pants .
# It dissappointed a ok job pressing his pants .
# It looked a ok job pressing his pants .
# It cost a aware job pressing his pants .
# It went a aware job pressing his pants .
# It looking a aware job pressing his pants .
# It mention a aware job pressing his pants .
# It crossing a aware job pressing his pants .
# It waste a aware job pressing his pants .
# It meddling a aware job pressing his pants .
# It ripped a aware job pressing his pants .
# It 'm a aware job pressing his pants .
# It like a aware job pressing his pants .
# It play a aware job pressing his pants .
# It supposed a aware job pressing his pants .
# It look a aware job pressing his pants .
# It were a aware job pressing his pants .
# It remained a aware job pressing his pants .
# It got a aware job pressing his pants .
# It surprised a aware job pressing his pants .
# It be a aware job pressing his pants .
# It shorted a aware job pressing his pants .
# It seemed a aware job pressing his pants .
# It threw a aware job pressing his pants .
# It use a aware job pressing his pants .
# It leaked a aware job pressing his pants .
# It would a aware job pressing his pants .
# It killed a aware job pressing his pants .
# It had a aware job pressing his pants .
# It suggest a aware job pressing his pants .
# It happens a aware job pressing his pants .
# It fall a aware job pressing his pants .
# It think a aware job pressing his pants .
# It Do a aware job pressing his pants .
# It saw a aware job pressing his pants .
# It LOST a aware job pressing his pants .
# It stop a aware job pressing his pants .
# It hurt a aware job pressing his pants .
# It do a aware job pressing his pants .
# It dissappointed a aware job pressing his pants .
# It looked a aware job pressing his pants .
# It cost a favorite job pressing his pants .
# It waste a favorite job pressing his pants .
# It ripped a favorite job pressing his pants .
# It shorted a favorite job pressing his pants .
# It leaked a favorite job pressing his pants .
# It killed a favorite job pressing his pants .
# It LOST a favorite job pressing his pants .
# It hurt a favorite job pressing his pants .
# It dissappointed a favorite job pressing his pants .
# It was a absolute job pressing his pants .
# It cost a absolute job pressing his pants .
# It looking a absolute job pressing his pants .
# It crossing a absolute job pressing his pants .
# It waste a absolute job pressing his pants .
# It meddling a absolute job pressing his pants .
# It ripped a absolute job pressing his pants .
# It 'm a absolute job pressing his pants .
# It like a absolute job pressing his pants .
# It supposed a absolute job pressing his pants .
# It look a absolute job pressing his pants .
# It were a absolute job pressing his pants .
# It remained a absolute job pressing his pants .
# It surprised a absolute job pressing his pants .
# It be a absolute job pressing his pants .
# It shorted a absolute job pressing his pants .
# It seemed a absolute job pressing his pants .
# It threw a absolute job pressing his pants .
# It use a absolute job pressing his pants .
# It leaked a absolute job pressing his pants .
# It would a absolute job pressing his pants .
# It killed a absolute job pressing his pants .
# It had a absolute job pressing his pants .
# It are a absolute job pressing his pants .
# It suggest a absolute job pressing his pants .
# It fall a absolute job pressing his pants .
# It prompted a absolute job pressing his pants .
# It LOST a absolute job pressing his pants .
# It stop a absolute job pressing his pants .
# It hurt a absolute job pressing his pants .
# It dissappointed a absolute job pressing his pants .
# It looked a absolute job pressing his pants .
# It cost a amazing job pressing his pants .
# It killed a amazing job pressing his pants .
# It LOST a amazing job pressing his pants .
# It hurt a amazing job pressing his pants .
# It dissappointed a amazing job pressing his pants .
# It cost a rich job pressing his pants .
# It mention a rich job pressing his pants .
# It waste a rich job pressing his pants .
# It supposed a rich job pressing his pants .
# It surprised a rich job pressing his pants .
# It shorted a rich job pressing his pants .
# It leaked a rich job pressing his pants .
# It would a rich job pressing his pants .
# It killed a rich job pressing his pants .
# It suggest a rich job pressing his pants .
# It happens a rich job pressing his pants .
# It think a rich job pressing his pants .
# It LOST a rich job pressing his pants .
# It hurt a rich job pressing his pants .
# It dissappointed a rich job pressing his pants .
# It looked a rich job pressing his pants .
# It cost a excited job pressing his pants .
# It looking a excited job pressing his pants .
# It mention a excited job pressing his pants .
# It waste a excited job pressing his pants .
# It meddling a excited job pressing his pants .
# It ripped a excited job pressing his pants .
# It like a excited job pressing his pants .
# It supposed a excited job pressing his pants .
# It look a excited job pressing his pants .
# It remained a excited job pressing his pants .
# It be a excited job pressing his pants .
# It shorted a excited job pressing his pants .
# It seemed a excited job pressing his pants .
# It threw a excited job pressing his pants .
# It use a excited job pressing his pants .
# It leaked a excited job pressing his pants .
# It would a excited job pressing his pants .
# It killed a excited job pressing his pants .
# It suggest a excited job pressing his pants .
# It think a excited job pressing his pants .
# It saw a excited job pressing his pants .
# It LOST a excited job pressing his pants .
# It hurt a excited job pressing his pants .
# It dissappointed a excited job pressing his pants .
# It looked a excited job pressing his pants .
# It cost a handy job pressing his pants .
# It waste a handy job pressing his pants .
# It shorted a handy job pressing his pants .
# It killed a handy job pressing his pants .
# It LOST a handy job pressing his pants .
# It hurt a handy job pressing his pants .
# It dissappointed a handy job pressing his pants .
# It cost a great job pressing his pants .
# It waste a great job pressing his pants .
# It killed a great job pressing his pants .
# It LOST a great job pressing his pants .
# It hurt a great job pressing his pants .
# It dissappointed a great job pressing his pants .
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
