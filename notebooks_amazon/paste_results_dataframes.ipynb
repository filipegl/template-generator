# %%
import pandas as pd

# %%
df = pd.read_clipboard(usecols=["template_index", "label", "original_text", "masked_text", "template_text"], dtype=str).dropna()
df["template_index"] = df["template_index"].map(lambda x: int(x)+1)
df
# Out:
#     template_index label                                      original_text
# 0                1     0  I am running windows 7 ultimate and a microsof...  \
# 1                2     1  If you think the image is too bright, you can ...
# 2                3     1  I ordered a book on March 14 for a birthday pr...
# 3                4     1  I think it would have been helpful to show how...
# 4                5     1  Grooves are solid on here and Instant Funk is ...
# 5                6     0  Unfortunately, it hasn't been worth the purcha...
# 6                7     0  I really do not feel that this tub deserves th...
# 7                8     1  I like how you can use multiple switches to ma...
# 8                9     1                                   Simple, you say?
# 9               10     0                This set is a box of useless trash.
# 10              11     1  Never slow-moving, not over anyone's head, and...
# 11              12     0       By the third time the water was gushing out.
# 12              13     0                                 From love to hate.
# 13              14     0  I luv Johanna Lindsey books but this was not g...
# 14              15     0                    I've never been so disapointed.
# 15              16     1  The main charters are king Arthur,Guenever,Gaw...
# 16              17     0  I'm sure bette wishes she could take this back...
# 17              18     1                 How do you teach that to your dog?
#
#                                           masked_text
# 0   I am running windows 7 {mask} and a microsoft ...  \
# 1   If you think the image is too {mask} , you can...
# 2   I {mask} a book on March 14 for a {mask} prese...
# 3   I think it {mask} {mask} been helpful to show ...
# 4   Grooves are {mask} on here and Instant Funk is...
# 5   Unfortunately , it {mask} n't been {mask} the ...
# 6   I really {mask} not feel that this tub {mask} ...
# 7   I like how you {mask} use multiple switches to...
# 8                               Simple , you {mask} ?
# 9             This set {mask} a box of {mask} trash .
# 10  Never slow-moving , not over anyone 's head , ...
# 11  By the {mask} time the water {mask} gushing out .
# 12                              From love to {mask} .
# 13  I luv Johanna Lindsey books but this was not {...
# 14                     I 've never {mask} so {mask} .
# 15  The main charters are king Arthur , Guenever ,...
# 16  I 'm {mask} bette wishes she could take this b...
# 17           How {mask} you {mask} that to your dog ?
#
#                                         template_text
# 0   I am running windows 7 {pos_adj} and a microso...
# 1   If you think the image is too {pos_adj} , you ...
# 2   I {pos_verb} a book on March 14 for a {neg_adj...
# 3   I think it {neg_verb} {pos_verb} been helpful ...
# 4   Grooves are {pos_adj} on here and Instant Funk...
# 5   Unfortunately , it {pos_verb} n't been {pos_ad...
# 6   I really {neg_verb} not feel that this tub {po...
# 7   I like how you {pos_verb} use multiple switche...
# 8                           Simple , you {neg_verb} ?
# 9      This set {neg_verb} a box of {neg_adj} trash .
# 10  Never slow-moving , not over anyone 's head , ...
# 11  By the {pos_adj} time the water {neg_verb} gus...
# 12                          From love to {neg_verb} .
# 13  I luv Johanna Lindsey books but this was not {...
# 14              I 've never {neg_verb} so {neg_adj} .
# 15  The main charters are king Arthur , Guenever ,...
# 16  I 'm {pos_adj} bette wishes she could take thi...
# 17   How {neg_verb} you {pos_verb} that to your dog ?

# %%
df.to_csv("generated_templates/generated_templates_random.csv", index=False)
